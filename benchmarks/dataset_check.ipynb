# %%
import pandas as pd

# %%
df = pd.read_csv("./ycsb_dataset_KV1K_2GB.csv")
df.head()
# Out:
#   opration                        key  \
# 0      put   user12161962213042174405
# 1      put   user09929646806074584996
# 2      put   user16626593026977353223
# 3      put   user14394277620009763814
# 4      put   user03232700585171816769
#
#                                                value
# 0   BgAAAGZpZWxkMNoDAAA1JiYxNDAiQH8zXDMiUHUrTic3W...
# 1   BgAAAGZpZWxkMNoDAAAtQCEsWz0gTCEtOiI6KD49QDkjW...
# 2   BgAAAGZpZWxkMNoDAAAzTT8wPioiOnI7MjwgQ20zPSgzM...
# 3   BgAAAGZpZWxkMNoDAAAlIj49RCU6LXo+JiAxTmEiXicqK...
# 4   BgAAAGZpZWxkMNoDAAAjNmgrKjYyJXg6ICo4J3Y3RyM1Q...

# %%
df["opration"].value_counts()
# Out:
# opration
# put    1599433
# get     523846
# Name: count, dtype: int64
